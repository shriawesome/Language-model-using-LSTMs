# %%
import numpy as np

from gen_char import read_file, process_data, build_model, SampleText

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, LSTM, Dense

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Parameter values

# %%
maxlen = 200
step = 3
hidden_nodes = 128
batch_size = 256

# %% [markdown]
# ## Reading input file

# %%
# chars : all the alphabets from A-Z and a-z including \n
input_path = 'first_name.txt'
text = read_file(input_path)
chars = sorted(set(text))

# %%
# Assigning indices to characters and vice versa for one-hot encoding
char_indices = {c:i for i, c in enumerate(chars)}
indices_char = {i:c for i, c in enumerate(chars)}

# %% [markdown]
# ## Preparing the data

# %%
# x, y one-hot encodings for input and labels
# sentences, next_chars - data in raw format
x, y, sentences, next_chars = process_data(text, chars, char_indices, maxlen, step)
x.shape, y.shape
# Out:
# ((2851, 200, 52), (2851, 52))

# %% [markdown]
# ## Model Architecture

# %%
def build_model():
    model = Sequential()
    model.add(LSTM(hidden_nodes, input_shape=(maxlen, len(chars))))
    model.add(Dense(len(chars), activation='softmax'))
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.RMSprop())
    
    return model

# %%
input_shape = (maxlen, len(chars))
output = len(chars)
model = build_model(input_shape, output)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               92672
#
#  dense_1 (Dense)             (None, 52)                6708
#
# =================================================================
# Total params: 99,380
# Trainable params: 99,380
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Helper fuctions and Callbacks

# %% [markdown]
# ## Training the Model

# %%
model.fit(x, y, batch_size=batch_size,
          epochs=150,
          callbacks=[SampleText(text, chars, char_indices, indices_char, maxlen)])
# Out:
# Epoch 1/150
# 12/12 [==============================] - ETA: 0s - loss: 3.3891
# diversity: 0.5
# Generated Text : ['r', 'a', 'n', 'hn', 'fnd', 'n', 't', 'ir', 'iun', 'r', 'a', 'rt', 'SQ', 't', 'r', 'n', 'tsi', 'ia', 'd', 'r', 'i', 'm', 'aa', 'r', 'r', 'ai', 'r', 'tk', 'nr', 'ra', 'ta', 'r', 't', 'ani', 'anr', 'g', 'titar', 'h', 'arnantta', 'e', 'r', 'a', 'rri', 'ea', 'ei', 'nrh', 'n', 'k', 'rh', 'i', 'r', 'a', 'a', 'era', 'esrenairi', 'ai', 'daai', 'ntii']
#
# 12/12 [==============================] - 18s 1s/step - loss: 3.3891
# Epoch 2/150
# 12/12 [==============================] - ETA: 0s - loss: 3.1228
# diversity: 0.5
# Generated Text : ['iaaih', 'her', 'tia', 'a', 'ajgsaraiaaaiaia', 'ah', 'aAil', 'Snaahiahsaa', 'yia', 'iiiaa', 'rn', 'ea', 'ra', 'Ph', 'haraid', 'iaa', 'ahS', 'j', 'i', 'uh', 'ia', 'ai', 'iiih', 'hiaa', 'iaaiihanSa', 'aha', 'iS', 'a', 'ahSsriaha', 'ahta', 'rs', 'S', 'hnSSaSaaa', 'iianahiihaha', 'ath', 'i', 'a', 'raab', 'SaA']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.1228
# Epoch 3/150
# 12/12 [==============================] - ETA: 0s - loss: 3.1053
# diversity: 0.5
# Generated Text : ['aaan', 'aaa', 'aara', 'aye', 'srhaeannaaaeshaadjathiinaaaaeaairhh', 'aaytananaaeiaairaantaaa', 'iayhaaaaa', 'a', 'aaJaaiayaa', 'uhmaaninarSaaaaaahaanhnniniiaaiailaaad', 'ina', 'y', 'emaaia', 'aird', 'aaaniitaaad', 'an', 'hheiaa', 'rraaani', 'aaBRaaaaaa']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.1053
# Epoch 4/150
# 12/12 [==============================] - ETA: 0s - loss: 3.0902
# diversity: 0.5
# Generated Text : ['a', 'ah', 'itraha', 'a', 'i', 'hiaeiha', 'aa', 'raS', 'ahAi', 'ty', 'aaau', 'a', 'aaaaaaha', 'a', 'ar', 'ahahiiAaa', 'ha', 'dra', 'ri', 'r', 'a', 'eaihia', 'S', 'hi', 'i', 'ah', 'aaa', 'aka', 'i', 'a', 'ah', 'ai', 'y', 'aar', 'a', 'ha', 'aaiSa', 'r', 'naaaakaa', 'aahaaaaam', 't', 'arr', 'aa', 'a', 'h', 'aia', 'rraaaa', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.0902
# Epoch 5/150
# 12/12 [==============================] - ETA: 0s - loss: 3.0758
# diversity: 0.5
# Generated Text : ['nihdain', 'Ays', 'au', 'Snuanhhai', 'aas', 'he', 'r', 'anhhn', 'a', 'Sh', 'h', 'nnsh', 'ii', 'haai', 'au', 'unheshaia', 'n', 'urh', 'An', 'whnhiihan', 'nn', 'h', 'uywnahh', 'ah', 'aiu', 'aiaha', 'a', 'raah', 'nh', 'sai', 'iihrha', 'm', 'nh', 'a', 'adA', 'hi', 'adhinnaaShi', 'h', 'unrdaa', 'l', 'eehhir', 'dhaah']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.0758
# Epoch 6/150
# 12/12 [==============================] - ETA: 0s - loss: 3.0623
# diversity: 0.5
# Generated Text : ['ea', 'ahiaahra', 'sw', 'h', 'r', 'hisaA', 'aa', 'ah', 'ihhauna', 'SA', 'aa', 'iheaaah', 'ja', 'aS', 'n', 'i', 'Sh', 'n', 'a', 'iai', 'h', 'hae', 'i', 'i', 'da', 'ieen', 'aha', 'wh', 'i', 'a', 'h', 'at', 'a', 'nhah', 'i', 'Snahus', 'r', 'daaah', 'yahhih', 'nj', 'h', 'inanhd', 'atsh', 'i', 'n', 'dha', 'ae', 'h', 'i', 'err']
#
# 12/12 [==============================] - 15s 1s/step - loss: 3.0623
# Epoch 7/150
# 12/12 [==============================] - ETA: 0s - loss: 3.0393
# diversity: 0.5
# Generated Text : ['nhainhaaataaahnara', 'ae', 'daaaahaun', 'aanbuaaj', 'Saia', 'Sa', 'ikaanai', 'taahriaaararunraa', 'ia', 'aaaatiaaakaaeat', 'ria', 'aaisi', 'a', 'ja', 'aaaTaa', 'aaa', 'draal', 'aauaeaadaaijaaae', 'anlaiaanaaaia', 'Aatlaiah', 'aarnahaahaaaaia', 'aih', 'aaiaai', 'asiin']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.0393
# Epoch 8/150
# 12/12 [==============================] - ETA: 0s - loss: 3.0229
# diversity: 0.5
# Generated Text : ['aanman', 'a', 'ara', 'ia', 'ahant', 'hsneha', 'na', 'na', 'i', 'Sahaaoa', 'h', 'aaha', 'sh', 'h', 'ara', 'n', 'tha', 'sh', 'ha', 'ah', 'theai', 'shauhaMt', 'dihia', 'aanhh', 'atah', 'ahahahShiihahat', 'hhi', 'Sah', 'a', 'ti', 'ahua', 'nnnun', 'm', 'r', 'a', 'a', 'rihaa', 'a', 'hana', 'nnahat', 'ahiShaha', 'aha', 'a']
#
# 12/12 [==============================] - 16s 1s/step - loss: 3.0229
# Epoch 9/150
# 12/12 [==============================] - ETA: 0s - loss: 2.9870
# diversity: 0.5
# Generated Text : ['n', 'innhiaa', 'haraai', 'raiaanaaa', 'ihaae', 'hakarai', 'iuainhaahaen', 'hashaatna', 'aa', 'ahaaanaa', 'aaaaar', 'araireatyaaKhaya', 'iaoaa', 'nadhaa', 'anartaaaja', 'naaaana', 'iaahaasarlananhaaa', 'raaauyiaSara', 'urataa', 'aranaharia', 'iua', 'aahria', 'arbwha', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.9870
# Epoch 10/150
# 12/12 [==============================] - ETA: 0s - loss: 2.9560
# diversity: 0.5
# Generated Text : ['hi', 'iinyi', 'iin', 'uiAitii', 'ihn', 'gaeiii', 'rhi', 'nikainiin', 'Saira', 'sui', 'PSrsien', 'an', 'riia', 'eaira', 'nsnni', 'i', 'kalaenisia', 'luiahia', 'raiar', 'niahaar', 'iaadr', 'hi', 'ahd', 'i', 'uaiim', 'iiii', 'ihar', 'daninih', 'iuiniayo', 'diiiri', 'ta', 'irisipi', 'aiiiii', 'iiu', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.9560
# Epoch 11/150
# 12/12 [==============================] - ETA: 0s - loss: 2.9118
# diversity: 0.5
# Generated Text : ['d', 'aea', 'aa', 'aaa', 'ai', 'raa', 'Aiay', 'raakaan', 'dar', 'a', 'a', 'ny', 'a', 'a', 'n', 'hshhia', 'a', 'nai', 'raia', 'a', 'aa', 'e', 'aean', 'ah', 'ara', 'naars', 'aea', 'ea', 'aa', 'nanjaa', 'aaa', 'ana', 'eaarea', 'iba', 'anh', 'Saaa', 'haaa', 'har', 'a', 'aansaa', 'aa', 'aut', 'a', 'Sanaa', 'Aana', 'na', 'a', 'a']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.9118
# Epoch 12/150
# 12/12 [==============================] - ETA: 0s - loss: 2.8543
# diversity: 0.5
# Generated Text : ['nimni', 'hra', 'n', 'nrsha', 'uhiha', 'an', 'inhai', 'nhhuanati', 'hanin', 'u', 'ahanih', 'arih', 'aa', 'in', 'shaiha', 'ann', 'han', 'inii', 'shhahan', 'nha', 'nan', 'nanh', 'ahhian', 'idinma', 'ahntaa', 'hainud', 'rarp', 'nAnih', 'hnhraa', 'nura', 'a', 'hi', 'ehun', 'yh', 'auii', 'anieha', 'nhit']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.8543
# Epoch 13/150
# 12/12 [==============================] - ETA: 0s - loss: 2.8015
# diversity: 0.5
# Generated Text : ['a', 'aysha', 'Sahrua', 'Saasha', 'aaaaa', 'aai', 'h', 'aa', 'hah', 'aa', 'uaas', 'aita', 'aaa', 'na', 'ana', 'aata', 'haha', 'aah', 'hahaka', 'aieha', 'aama', 'a', 'usa', 'aara', 'aakh', 'aa', 'haha', 'Aana', 'aan', 'imea', 'Sama', 'aui', 'a', 'ana', 'iahaa', 'auhi', 'ahaa', 'Nat', 'aaa', 'a', 'h']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.8015
# Epoch 14/150
# 12/12 [==============================] - ETA: 0s - loss: 2.7536
# diversity: 0.5
# Generated Text : ['aahahhandtaannannaia', 'uanraaa', 'aaenn', 'aea', 'adahi', 'jaahainaa', 'Sinnta', 'aaan', 'ahahasha', 'aehaha', 'a', 'ranta', 'iaanns', 'a', 'aashsh', 'aanarvSaahaeb', 'auileaa', 'amaiaae', 'anhaha', 'aaanhaaain', 'uahanan', 'anaaahaaaha', 'matyananai', 'eannh', 'ianNaaa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.7536
# Epoch 15/150
# 12/12 [==============================] - ETA: 0s - loss: 2.7178
# diversity: 0.5
# Generated Text : ['iha', 'iiiaeaha', 'aera', 'ihhaiaibaiahanhai', 'Dieibaharhanhain', 'Aahiithaaihiiaka', 'ehianiaanhahaaahaharaahauhahaahniehhaha', 'ialai', 'auiina', 'haishaahiiaaahaaldhahahyaieihahaahau', 'aahayhaeheahaaa', 'enha', 'aiaMahajaahaa', 'iueih']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.7178
# Epoch 16/150
# 12/12 [==============================] - ETA: 0s - loss: 2.6740
# diversity: 0.5
# Generated Text : ['Srara', 'ain', 'a', 'dari', 'Sarai', 'inka', 'rnuad', 'ann', 'anrne', 'Sanlan', 'Serda', 'idaa', 'Sarrha', 'aninh', 'i', 'aapnnh', 'unn', 'ikhaj', 'iaaan', 'aiain', 'Suhan', 'eaii', 'nanl', 'anani', 'Sarij', 'Narenn', 'Kielna', 'Ainan', 'Suiia', 'Paihaam', 'vaha', 'iPreh', 'Sanrha', 'ra']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.6740
# Epoch 17/150
# 12/12 [==============================] - ETA: 0s - loss: 2.6249
# diversity: 0.5
# Generated Text : ['a', 'riiha', 'Sama', 'aan', 'aaka', 'arai', 'yai', 'aana', 'Aoi', 'aiin', 'aiita', 'uarti', 'iaoi', 'aary', 'iunt', 'Naaii', 'Siaii', 'hian', 'Shua', 'ia', 'Airi', 'Saa', 'iaiK', 'aria', 'arish', 'Parania', 'ASaii', 'Aii', 'nin', 'Sia', 'iai', 'aani', 'iaaa', 'jaan', 'ashat', 'Aai', 'aiih', 'aita', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.6249
# Epoch 18/150
# 12/12 [==============================] - ETA: 0s - loss: 2.5864
# diversity: 0.5
# Generated Text : ['rahi', 'Peani', 'aara', 'Sashha', 'Sarta', 'eehar', 'Sannv', 'sheha', 'nrm', 'laa', 'weis', 'Passh', 'Suhauh', 'Shanssh', 'Sashs', 'aresha', 'Aanm', 'Adann', 'Paahaa', 'Alran', 'Sadan', 'i', 'Ahaa', 'hae', 'haa', 'anda', 'ahln', 'Sana', 'Rath', 'Sraasha', 'Sahad', 'shan', 'Aainsh', 'Navaha']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.5864
# Epoch 19/150
# 12/12 [==============================] - ETA: 0s - loss: 2.5491
# diversity: 0.5
# Generated Text : ['uhmana', 'Shahai', 'Sanha', 'Srdin', 'nair', 'SabhiS', 'Nat', 'ann', 'shidi', 'Syani', 'Sanda', 'Saan', 'Syasn', 'Sania', 'Shrshi', 'Menhuna', 'Sarach', 'Sarisa', 'dan', 'Shanish', 'Aandi', 'Sanie', 'Sashi', 'Nerhy', 'shil', 'Sanki', 'Sarahh', 'anntja', 'Suaud', 'Sany', 'Shin', 'Shan', 'j']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.5491
# Epoch 20/150
# 12/12 [==============================] - ETA: 0s - loss: 2.5057
# diversity: 0.5
# Generated Text : ['mini', 'Paieha', 'rani', 'anni', 'hirhanraa', 'risashi', 'Shuraa', 'nariha', 'Sananaha', 'Srani', 'aishar', 'rranii', 'haniea', 'Sunshia', 'Sharaiah', 'ararin', 'Srnie', 'airara', 'Aaran', 'ahan', 'Sarain', 'Saii', 'hanlhan', 'uavinia', 'aiita', 'haniahi', 'Drhanar', 'Suniia', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.5057
# Epoch 21/150
# 12/12 [==============================] - ETA: 0s - loss: 2.4725
# diversity: 0.5
# Generated Text : ['nam', 'Shetri', 'Aehan', 'Aehanha', 'Anaha', 'hhami', 'Shamma', 'Shanha', 'Shhakijk', 'Ramisha', 'Mamita', 'Makhiya', 'Aajath', 'Sanraan', 'anuh', 'erare', 'raaa', 'Ansha', 'Aha', 'Dhahi', 'Ahnan', 'Shansha', 'anrana', 'Sharha', 'Sanit', 'Ashat', 'Sunni', 'Bhar', 'lahal', 'Anehan', 'ar']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.4725
# Epoch 22/150
# 12/12 [==============================] - ETA: 0s - loss: 2.4485
# diversity: 0.5
# Generated Text : ['Rari', 'aan', 'Sarin', 'Adit', 'Aashi', 'Viri', 'Knyit', 'Sandii', 'Sri', 'Aueri', 'Arishi', 'Dipana', 'Areshi', 'Aanisn', 'iDurm', 'Nuna', 'Saha', 'Shena', 'Surer', 'Sana', 'Nuri', 'Rana', 'uha', 'Seshi', 'ia', 'aridha', 'Annbhin', 'Arin', 'Aanr', 'Sumid', 'urid', 'haha', 'Aran', 'Shit', 'Setis']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.4485
# Epoch 23/150
# 12/12 [==============================] - ETA: 0s - loss: 2.4111
# diversity: 0.5
# Generated Text : ['Shenp', 'Shan', 'ari', 'Shaa', 'Shani', 'Shran', 'Saha', 'Sanrn', 'ani', 'Shih', 'aea', 'ani', 'redh', 'Ainsh', 'Shash', 'Svinr', 'Sash', 'Shrish', 'Sha', 'in', 'da', 'ne', 'aan', 'Ari', 'SPred', 'iin', 'Shan', 'Aai', 'Snn', 'Sie', 'aniid', 'Sany', 'een', 'han', 'ihan', 'Sat', 'reni', 'Sani', 'Saa', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.4111
# Epoch 24/150
# 12/12 [==============================] - ETA: 0s - loss: 2.3977
# diversity: 0.5
# Generated Text : ['Siihaaa', 'Sarija', 'aryeya', 'aerha', 'Saavasha', 'Maani', 'Tisaha', 'Shitisha', 'Shurai', 'Shiyama', 'Mani', 'Shashadi', 'Aksha', 'rnima', 'Sharisha', 'Sradish', 'Sadhish', 'Prary', 'Vauhat', 'Shakaihi', 'Sumushan', 'Shaita', 'Aili', 'Ariyarh', 'Arashi', 'Shara', 'Anita', 'Sa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.3977
# Epoch 25/150
# 12/12 [==============================] - ETA: 0s - loss: 2.3461
# diversity: 0.5
# Generated Text : ['Aada', 'Sart', 'Ana', 'Aana', 'Aadi', 'Aan', 'Ssha', 'Mana', 'Saann', 'Arish', 'Anda', 'Saunh', 'Auai', 'Sica', 'Snit', 'euda', 'Sanda', 'Aran', 'Sha', 'Aeda', 'Shan', 'hamin', 'Man', 'Sama', 'Suvn', 'Saha', 'aeush', 'ana', 'Kasha', 'Pansh', 'Aa', 'na', 'aira', 'ia', 'Naala', 'Sata', 'Arana', 'Sash', 'Aara', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.3461
# Epoch 26/150
# 12/12 [==============================] - ETA: 0s - loss: 2.3336
# diversity: 0.5
# Generated Text : ['ara', 'Sarisha', 'Sareenkaa', 'Dahatan', 'Aaman', 'Aamabha', 'Siaka', 'iara', 'Saalan', 'Manna', 'Serara', 'Aama', 'ayasha', 'Aatan', 'Prasepanti', 'Sharila', 'Saitan', 'Dartta', 'Arakam', 'Ayanensh', 'Arra', 'ranesha', 'Aneyana', 'Aarakt', 'Vunaya', 'Sarana', 'Sasha', 'Sarar', 'Dush']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.3336
# Epoch 27/150
# 12/12 [==============================] - ETA: 0s - loss: 2.3149
# diversity: 0.5
# Generated Text : ['Aauea', 'Piuui', 'Shim', 'iahi', 'Aiush', 'PUishi', 'Shara', 'Ayaa', 'Sham', 'Vini', 'Mara', 'Sitia', 'Shari', 'Aan', 'inai', 'Sia', 'Aiu', 'Ashi', 'arigya', 'Suii', 'Ki', 'Arish', 'Shara', 'Shiri', 'Sara', 'Meit', 'Ayish', 'Ageik', 'Sadi', 'Aira', 'Shii', 'Aima', 'Suri', 'Mish', 'Siri', 'Arat', 'Arat', 'Sudi']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.3149
# Epoch 28/150
# 12/12 [==============================] - ETA: 0s - loss: 2.2883
# diversity: 0.5
# Generated Text : ['iu', 'Sariya', 'Shrany', 'Sanma', 'arya', 'Rani', 'Nanen', 'Sathi', 'Sanya', 'Shar', 'prnn', 'Nena', 'Shin', 'Dera', 'Arnta', 'Arkshan', 'Sanra', 'Shati', 'Manet', 'Nari', 'Naradha', 'Sunika', 'Mana', 'Shita', 'Sarnha', 'Aneini', 'Auran', 'Sana', 'Sanan', 'Raha', 'Aara', 'Aran', 'Aani', 'Saren', 'ar']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.2883
# Epoch 29/150
# 12/12 [==============================] - ETA: 0s - loss: 2.2651
# diversity: 0.5
# Generated Text : ['a', 'Sran', 'Siri', 'Mara', 'Surha', 'Sashan', 'Srani', 'Ashi', 'Mari', 'Ait', 'Additi', 'Aradi', 'Surusha', 'Karith', 'Aansha', 'Ashi', 'Saash', 'Mina', 'Sira', 'Aisha', 'Shamrer', 'Aun', 'Purish', 'Sharan', 'Sunish', 'Shanet', 'Samit', 'Aadhan', 'Arai', 'Nari', 'Ara', 'Arshi', 'Sarit', 'Vidii', 'Ara']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.2651
# Epoch 30/150
# 12/12 [==============================] - ETA: 0s - loss: 2.2441
# diversity: 0.5
# Generated Text : ['a', 'Aavara', 'Sama', 'Nanisha', 'Parhita', 'Shrikan', 'Manee', 'Shanana', 'Nania', 'Anasha', 'Prisham', 'Ashanan', 'Sati', 'Sutan', 'Shitanya', 'Sharanyan', 'Kevanata', 'Ahata', 'Samitan', 'Sansha', 'Aradara', 'Sushana', 'Shitata', 'Seritan', 'Snrana', 'Auria', 'praraj', 'Manna', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.2441
# Epoch 31/150
# 12/12 [==============================] - ETA: 0s - loss: 2.2316
# diversity: 0.5
# Generated Text : ['a', 'SadraR', 'Shint', 'Shat', 'Sanita', 'Shal', 'Sarit', 'Shirt', 'Sharshi', 'Senep', 'Shunshi', 'Aehnt', 'Nani', 'Shayen', 'Shani', 'Srsh', 'Saneya', 'Siti', 'Sarti', 'Shari', 'Shiri', 'Shar', 'Shisha', 'Shamt', 'Shannh', 'Prani', 'Radu', 'Siri', 'Shasha', 'Shuha', 'Saned', 'Sumen', 'Sani', 'ane']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.2316
# Epoch 32/150
# 12/12 [==============================] - ETA: 0s - loss: 2.2078
# diversity: 0.5
# Generated Text : ['Sirak', 'eryana', 'Nimii', 'Maraan', 'Siini', 'irivi', 'Aishua', 'Suidit', 'Areeira', 'Aatishit', 'Maayan', 'Ashiya', 'Annin', 'Anii', 'Saariti', 'Ashini', 'Samane', 'Detan', 'Adeesha', 'Jani', 'Ayai', 'Shamani', 'Aniti', 'Aishiti', 'Ahashunt', 'Sariya', 'Shint', 'Srila', 'Rinasha', 'Sh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.2078
# Epoch 33/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1891
# diversity: 0.5
# Generated Text : ['Sharash', 'Anan', 'Saran', 'Sahan', 'Vesha', 'Vana', 'Shita', 'Sania', 'Hal', 'Anaha', 'Ansha', 'Jatia', 'Sarana', 'Anie', 'Kadhama', 'Sitha', 'Arsha', 'Mara', 'Shaa', 'Shasha', 'Sarea', 'niva', 'Ahar', 'Sarar', 'Vanya', 'Shama', 'Kara', 'Sirara', 'Shana', 'Sanda', 'Mala', 'Sha', 'Naradh', 'Shara', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.1891
# Epoch 34/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1832
# diversity: 0.5
# Generated Text : ['i', 'Suha', 'Sha', 'ida', 'Shaea', 'Kaa', 'Aha', 'Sai', 'Iir', 'Shama', 'Shita', 'Shani', 'Satha', 'Shati', 'Shashi', 'Kaman', 'Sadhie', 'Shila', 'Shika', 'Rani', 'Shii', 'Sera', 'Neesha', 'Sadi', 'Shani', 'Kaan', 'area', 'Ahan', 'Shrai', 'Sharha', 'Shit', 'Aan', 'Vani', 'itaya', 'hiti', 'Aanu', 'Sian', 'San']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.1832
# Epoch 35/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1603
# diversity: 0.5
# Generated Text : ['Shadash', 'Shrea', 'Nann', 'Shee', 'Shera', 'Shar', 'Shash', 'Sora', 'Nir', 'Shan', 'Shan', 'San', 'San', 'Dan', 'Sicha', 'Seshun', 'Shansh', 'Shara', 'Shan', 'Arep', 'Nita', 'Shnta', 'Sarena', 'Man', 'Ata', 'Ariti', 'Bhan', 'Shrema', 'Rari', 'Shan', 'Shar', 'Shan', 'Sal', 'Shami', 'Sara', 'Sansha', 'Man', 'S']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.1603
# Epoch 36/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1538
# diversity: 0.5
# Generated Text : ['ashumr', 'Sarita', 'Nrenita', 'Suramish', 'Malendhari', 'Sharatha', 'Aanita', 'Sarmansh', 'Aramnara', 'Naima', 'iesha', 'Ashita', 'Suviman', 'Airan', 'Shanvtish', 'Naranin', 'Arrean', 'Marala', 'Deratan', 'Marisha', 'Maumiri', 'Aruthani', 'Shayanen', 'Jeeran', 'Seshin', 'Sar']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.1538
# Epoch 37/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1325
# diversity: 0.5
# Generated Text : ['Arashan', 'Parratete', 'Sarayan', 'Marashi', 'Sariashi', 'Shitaera', 'Aaudhira', 'Sarashi', 'Sandaua', 'Saibhai', 'Meeea', 'Shuu', 'Rayal', 'Ashan', 'Saradeeeeta', 'Ariti', 'Aanila', 'Shurita', 'Arara', 'Aashui', 'Vinvaresha', 'Arulandi', 'Aareeen', 'Areera', 'Ranthi', 'Aara']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.1325
# Epoch 38/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1152
# diversity: 0.5
# Generated Text : ['andeeta', 'Samanaka', 'Ashal', 'Anabhara', 'Anitan', 'Aetayan', 'Aiika', 'Nama', 'anyana', 'anali', 'Shalita', 'Shatida', 'Aranan', 'Anisha', 'Arakraya', 'Atita', 'Arita', 'Aratani', 'Aashara', 'Anshama', 'Shatamiti', 'Arayanata', 'Aradaya', 'Shavanti', 'Aita', 'Amanya', 'Arani']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.1152
# Epoch 39/150
# 12/12 [==============================] - ETA: 0s - loss: 2.1159
# diversity: 0.5
# Generated Text : ['an', 'Meeta', 'Anitha', 'Aashara', 'Sharasha', 'Samarani', 'Shadarae', 'Anti', 'ara', 'Karahanya', 'Shigalea', 'Prarata', 'Bhauraka', 'Parari', 'Shareeean', 'Prarasha', 'Shatal', 'Saransha', 'Sarjeethara', 'Karasha', 'Shatita', 'Pulana', 'Ashi', 'Arausha', 'Prashisha', 'Aaav']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.1159
# Epoch 40/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0962
# diversity: 0.5
# Generated Text : ['ya', 'Sharan', 'Siansh', 'Mashit', 'Sungiti', 'Aaniti', 'Prarind', 'Aandi', 'Nerit', 'Sirat', 'Nathat', 'Madrita', 'Srata', 'Sati', 'Sarhan', 'Arii', 'Shuranda', 'Sarari', 'Samita', 'Sarita', 'Surata', 'Sumara', 'Arandeeeparan', 'Anushi', 'Parati', 'Anuri', 'Sarinea', 'Diti', 'Sirand']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.0962
# Epoch 41/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0780
# diversity: 0.5
# Generated Text : ['iika', 'Mara', 'Muri', 'Ani', 'ia', 'Aeshi', 'Shuri', 'Anii', 'Shii', 'Aidi', 'Aushi', 'Mande', 'Nishi', 'Anui', 'Shain', 'Sudii', 'Suni', 'Seent', 'Soiti', 'Sui', 'Smuki', 'Saan', 'Mama', 'Aai', 'Auishi', 'Ariti', 'Ma', 'Aami', 'Ashi', 'Arid', 'Pali', 'uwei', 'Nandi', 'Sari', 'Sidi', 'Shuushi', 'Shati', 'Aes']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.0780
# Epoch 42/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0726
# diversity: 0.5
# Generated Text : ['ha', 'Anrenkha', 'Shdandin', 'Shrvinish', 'Nankini', 'Shishan', 'Shrurlna', 'Suminvan', 'Shitiran', 'Surinajshan', 'Shureyakshi', 'Srumantini', 'Shurishav', 'Nirishi', 'Sarushish', 'Arnshnnsh', 'Srilenl', 'Shteryuyar', 'Praydshir', 'Sallikann', 'Kandiun', 'Shabhu']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.0726
# Epoch 43/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0594
# diversity: 0.5
# Generated Text : ['Sirama', 'Sireep', 'Sharish', 'Srear', 'Rani', 'Panja', 'Shara', 'Seral', 'Shharra', 'Shura', 'Sdhiya', 'Sudhan', 'Shira', 'Swari', 'Shida', 'Surura', 'Shreer', 'Sharan', 'Shira', 'Ansh', 'Ari', 'Shunree', 'Shin', 'Seerha', 'Snran', 'Mar', 'Shuran', 'Shal', 'Sisha', 'Seraja', 'Shaeeesh', 'Sh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.0594
# Epoch 44/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0436
# diversity: 0.5
# Generated Text : ['iti', 'Aidii', 'Aashika', 'Madi', 'Ani', 'Pani', 'Aai', 'Maeda', 'Aninda', 'Mashi', 'Vaisha', 'Aaidi', 'Aanshi', 'Aaditi', 'Anili', 'Sarishi', 'Saradha', 'Akaji', 'Sajal', 'Maija', 'Taidi', 'Aani', 'aeei', 'Naran', 'Vuja', 'Anii', 'Siida', 'Kalid', 'Pai', 'Aishi', 'Karisha', 'Maii', 'Adii', 'Ahati', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.0436
# Epoch 45/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0344
# diversity: 0.5
# Generated Text : ['atish', 'Sanda', 'Swan', 'Shad', 'Raran', 'Sanja', 'Shara', 'Shan', 'Varja', 'Ansh', 'Shara', 'Shura', 'Anshan', 'Aanya', 'Shandra', 'Shandan', 'Saman', 'Sosha', 'Vamal', 'Banshu', 'Sadran', 'Shata', 'Dal', 'Suvan', 'Bhal', 'Rand', 'Vuna', 'Manni', 'Seena', 'Shala', 'Shanra', 'Prayansh', 'Narana']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.0344
# Epoch 46/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0150
# diversity: 0.5
# Generated Text : ['man', 'Solish', 'Sharra', 'Shudi', 'Prani', 'Anja', 'Shama', 'Shadha', 'Suran', 'Shara', 'Shubh', 'Ashiva', 'Srami', 'Aani', 'Shila', 'Shali', 'Anit', 'Aunik', 'Mora', 'Shuya', 'Shal', 'Shala', 'Shiga', 'Shita', 'Sharan', 'Shusha', 'Shanda', 'Shani', 'Saman', 'Parat', 'Shila', 'Vishi', 'Shama', 'Sa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 2.0150
# Epoch 47/150
# 12/12 [==============================] - ETA: 0s - loss: 2.0158
# diversity: 0.5
# Generated Text : ['Sanki', 'Shara', 'Anita', 'Suwan', 'Chant', 'Sandeep', 'Sonan', 'Saran', 'Sara', 'Shavan', 'Shuven', 'Ansha', 'Sankar', 'Shansh', 'Subhan', 'Shuyan', 'Soran', 'Sanish', 'San', 'Suran', 'Shan', 'Sethi', 'Sharan', 'Sani', 'Shan', 'Pransha', 'Kandia', 'Aani', 'Anni', 'San', 'Shina', 'Shanda', 'Sur']
#
# 12/12 [==============================] - 16s 1s/step - loss: 2.0158
# Epoch 48/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9962
# diversity: 0.5
# Generated Text : ['Aari', 'Arasha', 'Arila', 'Mani', 'Mali', 'Ariya', 'Mani', 'Aiti', 'Arar', 'Lata', 'Arai', 'Aridha', 'Arisha', 'Sumigi', 'Aesha', 'Pritik', 'Mami', 'Kalal', 'Paraka', 'Jai', 'Asha', 'Aral', 'Aidi', 'Arma', 'Arada', 'Aran', 'Mali', 'Prari', 'Dat', 'Arasha', 'Aral', 'Anisi', 'Ara', 'Asisi', 'Aivi', 'Vishi', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.9962
# Epoch 49/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9849
# diversity: 0.5
# Generated Text : ['n', 'Shia', 'Neeeha', 'Shara', 'Shaeeeea', 'Shushi', 'Aashi', 'Sarita', 'Raman', 'Sahara', 'Aami', 'Parit', 'Auyana', 'Satali', 'Sashie', 'Shareea', 'Shalan', 'Sarajeee', 'Dita', 'Saeeha', 'Sabhal', 'Saleeen', 'Sharash', 'Shala', 'Shudha', 'Sharan', 'Sali', 'Amita', 'Anidha', 'Shuoya', 'Sh']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.9849
# Epoch 50/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9687
# diversity: 0.5
# Generated Text : ['Shanakeep', 'Sharar', 'Shajan', 'Sheera', 'Shrthar', 'Sherabh', 'Shanta', 'Shusha', 'Suritha', 'Srirak', 'Niti', 'Andi', 'Arij', 'Senkar', 'Sertar', 'Sarija', 'Shala', 'Shrthar', 'Shiti', 'Shraya', 'Saleema', 'Nireet', 'Namama', 'Sreeeha', 'Sewal', 'Shan', 'Shama', 'Shreeeh', 'Prani']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.9687
# Epoch 51/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9575
# diversity: 0.5
# Generated Text : ['pra', 'Sharara', 'Shuran', 'Saryan', 'Suran', 'Deeshasha', 'Suyansha', 'Sitan', 'Shaeea', 'Sharan', 'Sarasha', 'Surama', 'Shearaya', 'Didanra', 'Sarasha', 'Parajan', 'Saran', 'Shanra', 'Suni', 'Shal', 'Sajan', 'Sita', 'Sharana', 'Shanea', 'Shanta', 'Soevan', 'Dashan', 'Vandeesh', 'Ar']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.9575
# Epoch 52/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9387
# diversity: 0.5
# Generated Text : ['a', 'Anika', 'Nitii', 'Arika', 'Ashanda', 'Ashikwa', 'Aridip', 'Arishi', 'Narishi', 'Ashwara', 'Adishak', 'Aanidha', 'Arita', 'Arisha', 'Aritik', 'Akabhika', 'Ashika', 'Arishil', 'Andii', 'Afishwara', 'Dirakannika', 'Karika', 'Asha', 'Aakduh', 'Ariki', 'Abhita', 'Arishi', 'A', 'Arita']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.9387
# Epoch 53/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9558
# diversity: 0.5
# Generated Text : ['ariyan', 'Aniti', 'Aanidha', 'Morika', 'Anira', 'Asesha', 'Ashiwa', 'Anish', 'Anisi', 'Arira', 'Aniti', 'Aridwa', 'Aniya', 'Yodiwan', 'Anit', 'Aharan', 'Akiti', 'Aniya', 'Antidi', 'Swaradti', 'Anyan', 'Arwin', 'Anidi', 'Anil', 'Aniti', 'Arita', 'Arita', 'Await', 'Shumara', 'Soudhir', 'Anri']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.9558
# Epoch 54/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9170
# diversity: 0.5
# Generated Text : ['dala', 'Maiti', 'Arikata', 'Areshava', 'Surasha', 'Anidi', 'Aruman', 'Abharam', 'Ariti', 'Aranik', 'Aniti', 'Niikan', 'Ashika', 'Anisha', 'Anicha', 'Areetha', 'Nanili', 'Karikea', 'Vihila', 'Niitia', 'Makasha', 'Arala', 'Ashira', 'Nagurita', 'Niraeep', 'Areiva', 'Akriita', 'Kageee']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.9170
# Epoch 55/150
# 12/12 [==============================] - ETA: 0s - loss: 1.9157
# diversity: 0.5
# Generated Text : ['nak', 'Shalan', 'Seerah', 'Shumanja', 'Sauni', 'Deehantash', 'Shashash', 'Shaleeeeh', 'Shrarannee', 'Sarni', 'Sani', 'Sushan', 'Shamansh', 'Sreetal', 'nar', 'Nireen', 'Nareen', 'Shandan', 'Sidal', 'Salil', 'Sathura', 'Shamann', 'eeepntash', 'Sararadha', 'Sushan', 'Saranan', 'Sa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.9157
# Epoch 56/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8930
# diversity: 0.5
# Generated Text : ['Shida', 'Andi', 'Ai', 'Andiki', 'Triti', 'Anjar', 'Soiija', 'Anid', 'Adnira', 'Anii', 'Ankika', 'Andii', 'Anik', 'Anili', 'Shiawi', 'Anidi', 'Ankishi', 'Aishi', 'Ashiti', 'Atiswia', 'Aniki', 'Anii', 'Amana', 'Ayani', 'Arani', 'Anid', 'Arandi', 'Aani', 'Anshi', 'Ariti', 'Saridha', 'Ashin', 'Mani']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.8930
# Epoch 57/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8824
# diversity: 0.5
# Generated Text : ['amin', 'Sanid', 'Yahin', 'Vilja', 'Arejeha', 'Naril', 'Samal', 'Neetesha', 'Anshil', 'Asdhin', 'Ashina', 'Andhin', 'Muhin', 'Shalanaja', 'Bhann', 'Nurjara', 'Ushita', 'Shidara', 'Shila', 'Shusha', 'Arisha', 'Anshida', 'Monin', 'Arshaa', 'Majmij', 'Mariti', 'Prashi', 'Andyar', 'Mendi', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.8824
# Epoch 58/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8632
# diversity: 0.5
# Generated Text : ['an', 'Soranya', 'Serthani', 'Sarrayan', 'Aranyan', 'Arant', 'Dendan', 'Shira', 'Anshwan', 'Karati', 'Narvan', 'Samal', 'Artish', 'Anyarit', 'Anitan', 'Anita', 'Ansibha', 'Answit', 'Ashwan', 'Auknsh', 'Ninan', 'Ani', 'Mandi', 'Annya', 'Annit', 'Ashi', 'Arit', 'Shatnita', 'Anvin', 'Arikha']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.8632
# Epoch 59/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8667
# diversity: 0.5
# Generated Text : ['a', 'Shara', 'Sharann', 'Saranta', 'Sananda', 'Shara', 'Deepra', 'Saradhan', 'Surasha', 'Saryansh', 'Sarati', 'Sansha', 'Shansha', 'Sramant', 'Shupansha', 'Sherasha', 'Sarat', 'Saresh', 'Shansha', 'Sara', 'Saaj', 'Shita', 'Sajay', 'Sani', 'Shara', 'Sevan', 'Sarata', 'Shala', 'Shama', 'S']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.8667
# Epoch 60/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8422
# diversity: 0.5
# Generated Text : ['ra', 'Shurnda', 'Shin', 'Shiti', 'Artkni', 'Shrika', 'Makika', 'Aral', 'Shansha', 'Sudidi', 'Shrad', 'Surtan', 'Karika', 'Anik', 'Anyan', 'Shara', 'Shira', 'Shari', 'Sharan', 'Sakran', 'Shadni', 'Shurin', 'Shrith', 'Aritikan', 'Ariti', 'Anudhan', 'Ashina', 'Sarikhan', 'Mokin', 'Priman', 'A']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.8422
# Epoch 61/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8335
# diversity: 0.5
# Generated Text : ['han', 'Ashin', 'Ariti', 'Anshi', 'Sadushi', 'Shatiri', 'Somita', 'Ansha', 'Mami', 'Arta', 'Masha', 'Ada', 'Ansh', 'Arati', 'Samida', 'Samadha', 'Samanma', 'Soshan', 'Samdan', 'Shima', 'Shamansh', 'Sharman', 'Samar', 'Shalan', 'Shara', 'Soshi', 'Sabhanda', 'Swaya', 'Shurat', 'Ashil', 'Arit', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.8335
# Epoch 62/150
# 12/12 [==============================] - ETA: 0s - loss: 1.8185
# diversity: 0.5
# Generated Text : ['Shadri', 'Shal', 'Aryal', 'Dira', 'Shama', 'Shudi', 'Sharaya', 'Shala', 'Shala', 'Shama', 'Sumira', 'Shatika', 'Shiva', 'Shita', 'Shuha', 'Shaya', 'Shura', 'Suraha', 'Shadan', 'Shadera', 'Shira', 'Shreesh', 'Sharana', 'Samit', 'Surama', 'Ashim', 'Shulita', 'Shala', 'Shala', 'Sarsha', 'Sha']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.8185
# Epoch 63/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7942
# diversity: 0.5
# Generated Text : ['ira', 'Shira', 'Sharara', 'Sharal', 'Shurasha', 'Arshan', 'Sarshi', 'Sarya', 'Shala', 'Shalya', 'Shurasha', 'Shraga', 'Shura', 'Sharan', 'Sharan', 'Shiraa', 'Sharal', 'Shashan', 'Samila', 'Shalit', 'Sorina', 'Soral', 'Shira', 'Shrita', 'Shrara', 'Shala', 'Shura', 'Shardha', 'Sulisha', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.7942
# Epoch 64/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7939
# diversity: 0.5
# Generated Text : ['alina', 'Aodhin', 'Pralani', 'Samanda', 'Sodhila', 'Sharita', 'Sotilara', 'Shuryan', 'Sharasha', 'Seehana', 'Shitil', 'Sharusha', 'Soraran', 'Sharenya', 'Saharusha', 'Saritia', 'Sarisha', 'Sureeha', 'Shatil', 'Shalan', 'Sealaa', 'Saeshana', 'Sartiva', 'Shurerea', 'Shureep']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.7939
# Epoch 65/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7802
# diversity: 0.5
# Generated Text : ['Salkanat', 'Antiv', 'Ashan', 'Staan', 'Suman', 'Raanshi', 'Sharita', 'Shavavaya', 'Shalara', 'Shagant', 'Soragasha', 'Sali', 'Sudhan', 'Aamani', 'Shalaya', 'Seera', 'Ashita', 'Araka', 'Ashin', 'Arasha', 'Antin', 'Anndee', 'Shami', 'Shita', 'Kushand', 'Akshi', 'Aniya', 'Arish', 'Arsh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.7802
# Epoch 66/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7650
# diversity: 0.5
# Generated Text : ['rtika', 'Shita', 'Manik', 'Ranteee', 'Tani', 'Anak', 'Shaeel', 'Nareet', 'Saran', 'Serta', 'Shayara', 'Shara', 'Sasha', 'Parana', 'Paran', 'Anan', 'Shala', 'Shara', 'Shamana', 'Sharan', 'Samanda', 'Meeeta', 'Narat', 'Mara', 'Maka', 'Naina', 'Surama', 'Sandha', 'Sarena', 'Samaya', 'Sasha', 'Sa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.7650
# Epoch 67/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7431
# diversity: 0.5
# Generated Text : ['Shiman', 'Sharava', 'Shal', 'Tareeh', 'Sarara', 'Sharya', 'Shueta', 'Shijala', 'Siri', 'Shradaray', 'Shal', 'Seethal', 'Sharya', 'Shadraya', 'Shreran', 'Sharava', 'Suvara', 'Sharaja', 'Swara', 'Shaleet', 'Shalara', 'Sharareet', 'Shrevareth', 'Sharapanti', 'Sharasha', 'Sharee']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.7431
# Epoch 68/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7530
# diversity: 0.5
# Generated Text : ['Shan', 'Ardha', 'Shrala', 'Shaleet', 'Shurala', 'Samila', 'Jajeeet', 'Nareva', 'Suriya', 'Prayan', 'Sudala', 'Sajal', 'Sabheer', 'aranan', 'Sareen', 'Swranyan', 'Pran', 'Surama', 'Sharyan', 'Shale', 'Sahalla', 'Shamar', 'Paryan', 'Dila', 'Saryal', 'Sharal', 'Soiita', 'Shaladra', 'Je']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.7530
# Epoch 69/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7176
# diversity: 0.5
# Generated Text : ['a', 'Arivin', 'Viir', 'Mufuwin', 'Mabhini', 'Arini', 'Ashanwi', 'Anishwa', 'Atishwdwa', 'Arshan', 'Akanik', 'Ashuran', 'Arir', 'Awuni', 'Anwa', 'Yorifi', 'Anii', 'Andiria', 'Shiranshwa', 'Arinin', 'Ariyan', 'Karadwi', 'Niari', 'Miwa', 'Anidi', 'Ariti', 'Anira', 'Anita', 'Ardhida', 'Anit']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.7176
# Epoch 70/150
# 12/12 [==============================] - ETA: 0s - loss: 1.7081
# diversity: 0.5
# Generated Text : ['Shwava', 'Soujal', 'Namali', 'Nija', 'Mari', 'ura', 'Anshi', 'Andi', 'Arshwa', 'Anshi', 'Arish', 'Arika', 'Amiti', 'Andidha', 'Ridhi', 'Anni', 'Amrit', 'Aniti', 'Anidha', 'Arini', 'Andhi', 'Andhal', 'Anmir', 'Anika', 'Anbha', 'Andha', 'Andhi', 'Sharshi', 'Ashina', 'Ashit', 'Ankain', 'Naina', 'A']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.7081
# Epoch 71/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6988
# diversity: 0.5
# Generated Text : ['t', 'Hannka', 'Shaya', 'Pansha', 'Anish', 'Saran', 'Prani', 'Saman', 'Sovin', 'Shida', 'Sharya', 'Saran', 'Anjee', 'Prati', 'Arit', 'Ashina', 'Ashiv', 'Ankksha', 'Ashan', 'Anika', 'Anki', 'Shida', 'Sudhi', 'Sham', 'Surash', 'Shanya', 'Shitha', 'Sushur', 'Sheun', 'Sayi', 'Shuya', 'Shunja', 'Sija', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.6988
# Epoch 72/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6851
# diversity: 0.5
# Generated Text : ['Ranvasha', 'Divanshaman', 'Ashuswan', 'Samanda', 'Mali', 'Sharala', 'Parena', 'Pran', 'Nanda', 'Mani', 'Pranya', 'Paransha', 'Pranit', 'Prransha', 'Naran', 'Apun', 'Shakana', 'Shiran', 'Sonil', 'Sharidha', 'Sravina', 'Sakhan', 'Serana', 'Sajil', 'Neeta', 'Rati', 'Dira', 'Kashik', 'A']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.6851
# Epoch 73/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6550
# diversity: 0.5
# Generated Text : ['ndrar', 'Amarshita', 'Anditi', 'Praritin', 'Malika', 'Moiti', 'Mudidi', 'Anida', 'Maneen', 'Rarai', 'Amiti', 'Andhit', 'Aryankha', 'Neeeta', 'Rathi', 'Vinti', 'Mamini', 'Midik', 'Ashudrana', 'Aniya', 'Prabhin', 'Pranikir', 'Neennda', 'Pritij', 'Shardhan', 'Shumi', 'Surusha', 'Ayan']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.6550
# Epoch 74/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6458
# diversity: 0.5
# Generated Text : ['ima', 'Sashika', 'Shayash', 'Surav', 'Shaniya', 'Shala', 'Shareep', 'Shanyan', 'Soshi', 'Ankaksh', 'Ankar', 'Anti', 'Kandka', 'Shii', 'Anda', 'Nidit', 'Saida', 'Arshi', 'Andit', 'Andit', 'Samika', 'Shila', 'Nieet', 'Ranti', 'Sadrak', 'Seshan', 'Saryanik', 'Salka', 'Shila', 'Shuvin', 'Shula']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.6458
# Epoch 75/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6281
# diversity: 0.5
# Generated Text : ['Kamit', 'Mara', 'Ariti', 'Pranika', 'Naidha', 'Marit', 'Murita', 'Jagiya', 'Raim', 'Nurila', 'Kalish', 'Andi', 'Arshi', 'Aradi', 'Akanan', 'Anit', 'Andira', 'Shira', 'Monit', 'Matikaraa', 'Maman', 'Mareeepa', 'Praniya', 'Shara', 'Shushra', 'Shaubhi', 'Shuru', 'Shresha', 'Surit', 'Anis']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.6281
# Epoch 76/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6203
# diversity: 0.5
# Generated Text : ['a', 'Shreee', 'Suthan', 'Sakajan', 'Vii', 'Shradha', 'Shadhu', 'Shandan', 'Shandee', 'Shrreep', 'Preth', 'Neeta', 'Natkni', 'Van', 'Rijee', 'Prreshw', 'Nadrtep', 'Rashika', 'Vashal', 'Deena', 'Panyan', 'Karan', 'Jadhi', 'Shar', 'ushi', 'Amran', 'Janya', 'Meerat', 'Niral', 'Dish', 'Mamikar']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.6203
# Epoch 77/150
# 12/12 [==============================] - ETA: 0s - loss: 1.6082
# diversity: 0.5
# Generated Text : ['ransh', 'Saljal', 'Shilal', 'Sadhila', 'Shogyal', 'Ashal', 'Sateet', 'Shashan', 'Snavan', 'Suritha', 'Nariti', 'Mama', 'Anipa', 'Rajadeep', 'Pranheen', 'Suramansh', 'Sumal', 'Shulal', 'Somila', 'Shareep', 'Sheethan', 'Shalla', 'Seepra', 'Shulal', 'Shajala', 'Seeethantha', 'Deer']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.6082
# Epoch 78/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5718
# diversity: 0.5
# Generated Text : ['t', 'Meeet', 'Niti', 'Vini', 'Di', 'Arshikan', 'Ashava', 'Aditi', 'Ashidad', 'Mentenr', 'Niteepra', 'Naeeth', 'Mohi', 'Astika', 'Mahaka', 'Maidi', 'Jaman', 'Valeepa', 'Narila', 'Prajeep', 'Pranida', 'Paman', 'Arudhara', 'Aravi', 'Nanita', 'Vareeya', 'Narasha', 'Aarya', 'Antika', 'Amiti', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.5718
# Epoch 79/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5809
# diversity: 0.5
# Generated Text : ['nkam', 'Aramal', 'Shala', 'Sodil', 'Shalashan', 'Sashaka', 'Shishara', 'Samisha', 'Anmusha', 'Soryaman', 'Shavanya', 'Shumanv', 'Shala', 'Shalal', 'Shila', 'Sorijeen', 'Samita', 'Seuma', 'Vimert', 'Pruyan', 'Parsha', 'Shamila', 'Shamal', 'Samila', 'Sharesha', 'Sadhala', 'Samima']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.5809
# Epoch 80/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5618
# diversity: 0.5
# Generated Text : ['tika', 'Shayal', 'Naeeepa', 'Nanjesh', 'Sari', 'Seeyan', 'Srajesh', 'Sakreeta', 'Shurad', 'Samira', 'Saryan', 'Suritha', 'Sarishi', 'Shitish', 'Sratika', 'Shida', 'Sadharn', 'Samamra', 'Prandesh', 'Shaditya', 'Sodural', 'Salil', 'Shital', 'Shaujash', 'Seryandika', 'Sursha', 'Sh']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.5618
# Epoch 81/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5304
# diversity: 0.5
# Generated Text : ['rshika', 'Matikan', 'Makan', 'Naika', 'Nijeeh', 'Nreesha', 'Susha', 'Ratin', 'Andhi', 'Akisha', 'Alitanini', 'Ariti', 'Ankakanika', 'Anin', 'Andhin', 'Abhribha', 'Saditi', 'Anika', 'Ashidaa', 'Anmii', 'Amikani', 'Aritansha', 'Ashiwan', 'Avin', 'Ashika', 'Anuiishi', 'Ashwina', 'Ani']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.5304
# Epoch 82/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5315
# diversity: 0.5
# Generated Text : ['nushata', 'Asrivi', 'Sramashu', 'Maritman', 'Aedhala', 'Paresha', 'Nandra', 'Risha', 'Praksha', 'Nanida', 'Saman', 'Shala', 'Aoshana', 'Saryansh', 'Srusha', 'Shovana', 'Sukavnana', 'Tanin', 'Pranshu', 'Sarasha', 'Seeshan', 'Shallal', 'Samanrareep', 'Tanshira', 'Aaridhan', 'P']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.5315
# Epoch 83/150
# 12/12 [==============================] - ETA: 0s - loss: 1.5194
# diversity: 0.5
# Generated Text : ['sh', 'Samandee', 'Shnivan', 'Pranjeep', 'Sarguhil', 'Samima', 'Asisha', 'Aratika', 'Andi', 'Amandha', 'Anidha', 'Shauvi', 'Diyarneera', 'Vanni', 'Saima', 'ShrulanShan', 'Sojjeeta', 'Sujita', 'Sajini', 'Shila', 'Sushal', 'Samajeen', 'Sethatan', 'Deerata', 'Veenpnna', 'Dan', 'Ama']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.5194
# Epoch 84/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4893
# diversity: 0.5
# Generated Text : ['ral', 'Shayan', 'Paandha', 'Pranni', 'Sari', 'Kandi', 'Meid', 'Modi', 'Meeta', 'Ashukan', 'Majeedh', 'Neeetha', 'Nanjesh', 'Ma', 'Monur', 'Mamanka', 'Meeapa', 'Nanit', 'Gari', 'Prane', 'Ehash', 'Rapi', 'Samanl', 'Shaman', 'Sureethan', 'Neeera', 'Shal', 'jeeeep', 'Sima', 'Arshi', 'Andi', 'Ashi']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.4893
# Epoch 85/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4886
# diversity: 0.5
# Generated Text : ['Sarhi', 'Shrris', 'Surabha', 'Savish', 'Shrala', 'Shagura', 'Sobhalan', 'Sureerha', 'Srryinar', 'Sarita', 'Shavandee', 'Ansha', 'Surreep', 'Sarushi', 'Sramai', 'Sakarhara', 'Sheerata', 'Shravansh', 'Srshavida', 'Sharama', 'Shuran', 'Siravand', 'Suril', 'Shriram', 'Suriya', '']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.4886
# Epoch 86/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4681
# diversity: 0.5
# Generated Text : ['a', 'Vansha', 'Sareesh', 'Shryaryan', 'Sundhal', 'Shageeet', 'Shryaray', 'Sanmareepa', 'Sashid', 'Saryan', 'Shrepantee', 'Shrrasha', 'Sara', 'Sothila', 'Shareesh', 'Shrvanya', 'Shav', 'Surjeepha', 'Srakaya', 'Sheepa', 'Sheepranya', 'Karava', 'Bhaveetha', 'Paryayash', 'Sh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.4681
# Epoch 87/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4492
# diversity: 0.5
# Generated Text : ['arikar', 'Mai', 'Marik', 'Priika', 'Mani', 'Prayan', 'Maika', 'Nirikra', 'Praishi', 'Prakhinarak', 'Naran', 'Niri', 'Prikan', 'Praina', 'Prajit', 'Surajepra', 'Shaveeta', 'Namil', 'Naren', 'Arish', 'Sadarik', 'Madiki', 'Nain', 'Meeeth', 'Nitika', 'Manika', 'Pratik', 'Marika', 'Mami', 'M']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.4492
# Epoch 88/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4436
# diversity: 0.5
# Generated Text : ['Sramisha', 'Sardita', 'Shatita', 'Sushara', 'Samani', 'Surima', 'Shriyan', 'Suritha', 'Srayani', 'Suradhar', 'Subhi', 'Surayan', 'Subha', 'Shatibha', 'Sarshib', 'Sramiti', 'Satiti', 'Atitheerath', 'Arush', 'Abhandad', 'Sudi', 'Samal', 'Shaleeth', 'Shalaleep', 'Shalleep', 'Sh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.4436
# Epoch 89/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4228
# diversity: 0.5
# Generated Text : ['Maamira', 'Prayanya', 'Mani', 'Ariti', 'Prashi', 'Anti', 'Anditi', 'Araditi', 'Amandra', 'Ahuna', 'Arakhan', 'Arabhan', 'Aruti', 'Manita', 'Arshita', 'Anika', 'Anita', 'Ahita', 'Arashara', 'Soribh', 'Kariti', 'Anti', 'Mani', 'Merit', 'Nitili', 'Nira', 'Aridha', 'Karani', 'Arala', 'Aani']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.4228
# Epoch 90/150
# 12/12 [==============================] - ETA: 0s - loss: 1.4005
# diversity: 0.5
# Generated Text : ['aleep', 'Seepranshi', 'Sarreeer', 'Shuryatha', 'Sudika', 'Shadita', 'Shaleenta', 'Rashiri', 'Saumdreep', 'Sohyalan', 'Salan', 'Sojela', 'Surajika', 'Sudidi', 'Swratin', 'Shangeeta', 'Sumityan', 'Sarasha', 'Sharshiti', 'Sam', 'Aresha', 'Kantiti', 'Nini', 'Shurujal', 'Deent']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.4005
# Epoch 91/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3924
# diversity: 0.5
# Generated Text : ['ten', 'Ranrat', 'Kashini', 'Maini', 'Anika', 'Ashikaa', 'Kandid', 'Midi', 'Jerati', 'Ankaka', 'Shuba', 'Prajeen', 'Naran', 'Naret', 'Nrusha', 'Artyina', 'Parika', 'Nivin', 'Sudrij', 'Shrarya', 'Shurath', 'Shandal', 'Shureetha', 'Shrila', 'Saridha', 'Sudida', 'Arshita', 'Sartik', 'As']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.3924
# Epoch 92/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3533
# diversity: 0.5
# Generated Text : ['idha', 'Sobuja', 'Pralyan', 'Saraya', 'Rangur', 'Neersh', 'Swaraya', 'Sonsil', 'Dil', 'Arushu', 'Anyam', 'Ashita', 'Aniti', 'Anshi', 'Aunshi', 'Arwanit', 'Shurith', 'Meenta', 'Neethan', 'Neeeta', 'Fenta', 'Natin', 'Sajjija', 'Meenreth', 'Nantyaa', 'Samidr', 'Meethal', 'Naleep', 'Pra']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.3533
# Epoch 93/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3585
# diversity: 0.5
# Generated Text : ['andi', 'Anidha', 'Neeeepa', 'Natit', 'Dili', 'Deevanthaya', 'Raushi', 'Shal', 'Shuyan', 'Shilal', 'Sheetha', 'Sarjeeta', 'Shariya', 'Shaldasha', 'Sreshana', 'Shuryan', 'Suryayan', 'Vila', 'Ashila', 'Shiriya', 'Suraya', 'Shileep', 'Samila', 'Sathiswa', 'Surutyan', 'Saryan', 'Sur']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.3585
# Epoch 94/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3225
# diversity: 0.5
# Generated Text : ['Kareeta', 'Neeetat', 'Najeet', 'Najeep', 'Najeeta', 'Naidija', 'Neejeth', 'Neeeyansh', 'Ralla', 'Seevan', 'Dila', 'Vajjjeta', 'Naeedha', 'Neetha', 'Namila', 'Dija', 'Shuyaje', 'Vijeth', 'Vurash', 'Aan', 'Manili', 'Sujaya', 'Sujalee', 'Nijeenn', 'Nijal', 'Merit', 'Nritisha', 'Mar']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.3225
# Epoch 95/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3499
# diversity: 0.5
# Generated Text : ['Anal', 'Ashiba', 'Sudii', 'Andiya', 'Shawal', 'Shayanya', 'Niman', 'Surahi', 'Sadhida', 'Shala', 'Shaleepa', 'Sothala', 'Sai', 'Vishan', 'Mamiya', 'Sudi', 'Abhai', 'Andi', 'Sandi', 'Shara', 'Shala', 'Sahal', 'Samila', 'Shalal', 'Soeepa', 'Shayana', 'Sura', 'Anitha', 'Shurad', 'Shayansh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.3499
# Epoch 96/150
# 12/12 [==============================] - ETA: 0s - loss: 1.3109
# diversity: 0.5
# Generated Text : ['Sushi', 'Akshanta', 'Shanid', 'Shurbhit', 'Sarita', 'Shreet', 'Shuyan', 'Shul', 'Shala', 'Shali', 'Shijal', 'Shila', 'Switan', 'Shuriti', 'Sushit', 'Sutyani', 'Sarith', 'Arshun', 'Anth', 'Anti', 'Vandhi', 'Anik', 'Anikha', 'Anitha', 'Aridi', 'Anddha', 'Asha', 'Mankan', 'Archin', 'Andhir']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.3109
# Epoch 97/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2862
# diversity: 0.5
# Generated Text : ['Arayashi', 'Adrishwa', 'Aduyash', 'Madeeta', 'Naetha', 'Neetan', 'Shala', 'Shala', 'Suraja', 'Shariya', 'Soriya', 'Shakara', 'Sayanni', 'Rageeth', 'Neetash', 'Sharageeetha', 'Ravangu', 'Dilaja', 'Suagjeeepa', 'Saryan', 'Suraya', 'Shreeeya', 'Suraleepa', 'Senil', 'Shajal', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.2862
# Epoch 98/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2884
# diversity: 0.5
# Generated Text : ['othal', 'Samina', 'Sarhi', 'Sohil', 'Sholan', 'Subhandha', 'Suriyan', 'Surthanr', 'Shureen', 'Shulina', 'Sharnda', 'Somarsh', 'Shalal', 'Sankeep', 'Shahagnn', 'San', 'Suthan', 'Subhama', 'Srudhi', 'Shamanti', 'Shal', 'Sadhir', 'Shulyan', 'Shala', 'Sanjeen', 'Sorija', 'Sokri', 'And']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.2884
# Epoch 99/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2635
# diversity: 0.5
# Generated Text : ['dila', 'Mahanendra', 'Khamashi', 'Saddaree', 'Payansha', 'Shriyaksh', 'Suddadha', 'Sotit', 'Shulal', 'Shajesh', 'Sorula', 'Shoshan', 'Surash', 'Anshi', 'Samsiri', 'Sushil', 'Shandaree', 'Shavandeep', 'Shamasha', 'Sarika', 'Pranikan', 'Pranjeeh', 'Shuragya', 'Shrita', 'So']
#
# 12/12 [==============================] - 15s 1s/step - loss: 1.2635
# Epoch 100/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2427
# diversity: 0.5
# Generated Text : ['wa', 'Soui', 'Shamansh', 'Suryan', 'Sheera', 'Shila', 'Shali', 'Sandeep', 'Shiti', 'Suriya', 'Shiit', 'Shuli', 'Shali', 'Shul', 'Shgalla', 'Sali', 'Salin', 'Sheera', 'Shil', 'Shiven', 'Suri', 'Shalla', 'Shida', 'Shuyan', 'Shanla', 'Sheeep', 'Shila', 'Sheran', 'Shidra', 'Sheepra', 'SheranSh']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.2427
# Epoch 101/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2187
# diversity: 0.5
# Generated Text : ['rrmsr', 'Praya', 'Payaka', 'Nanid', 'Shar', 'Shreep', 'Sotibha', 'Srarika', 'Saraya', 'Shreyan', 'Shila', 'Shiral', 'Shiraya', 'Soubhi', 'Sarmibh', 'Sarimi', 'Shrala', 'Sotin', 'Shrala', 'Shabari', 'Saravan', 'Sandura', 'Sorili', 'Sariti', 'Arusha', 'Aram', 'Anjad', 'Yethila', 'Niril']
#
# 12/12 [==============================] - 16s 1s/step - loss: 1.2187
# Epoch 102/150
# 12/12 [==============================] - ETA: 0s - loss: 1.2153
# diversity: 0.5
# Generated Text : ['hil', 'Shithana', 'Sanma', 'Shraja', 'Sajiee', 'Sanitan', 'Shala', 'Sujeeet', 'Shumila', 'Sreeena', 'Shwalat', 'Veevnna', 'Daglasha', 'Aniya', 'Shijal', 'Arijeep', 'Shutil', 'Shalilee', 'Sanima', 'Shuraja', 'Shayani', 'Salal', 'Sumamra', 'Sarajep', 'Sadhil', 'Sonal', 'Shalal', 'Sh']
#
# ...
# Generated Text : ['dida', 'Shriya', 'Suriya', 'Shritil', 'Shudil', 'Shryanni', 'Sakhura', 'Shrobhan', 'Sidhar', 'Sushiva', 'Shujal', 'Shalila', 'Saneeta', 'Rashwnda', 'Sagijeep', 'Pyatansha', 'Yatitit', 'Mosid', 'Yohwata', 'Sadira', 'Shiraya', 'Sulil', 'Anshila', 'Soribi', 'Suriti', 'Arani', 'Ar']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.9920
# Epoch 117/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9746
# diversity: 0.5
# Generated Text : ['yala', 'Meehant', 'Shulama', 'Sojali', 'Dal', 'Sumashr', 'Praryaya', 'NanikaNamar', 'Peranveet', 'Nashwal', 'Majet', 'Maushu', 'Malankay', 'Maneera', 'Neetha', 'Rani', 'Prashin', 'Shantali', 'Shural', 'Naeesh', 'Nitit', 'Satishi', 'Shaventi', 'Shrthama', 'Samara', 'Paryan', 'Da']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.9746
# Epoch 118/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9675
# diversity: 0.5
# Generated Text : ['ankid', 'Panij', 'Jahandeera', 'Shavshu', 'Sarmir', 'Saryaha', 'Sandhi', 'Shrgyani', 'Surtita', 'Andiya', 'Shureet', 'Shamila', 'Soriya', 'Jatika', 'Atishi', 'Amiti', 'Ayandhi', 'Abhibhan', 'Arritan', 'Sammari', 'Sareethan', 'Anmala', 'Samindi', 'Suriya', 'Shraraya', 'Surash']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.9675
# Epoch 119/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9370
# diversity: 0.5
# Generated Text : ['hanshake', 'Sathalalaa', 'Preethan', 'Mangchi', 'Madiki', 'Makashakakekha', 'Neetada', 'Nashi', 'Rajeesh', 'Sabakakkukan', 'Kandada', 'Shurija', 'Shurayanka', 'Narshit', 'Saroshik', 'Ankala', 'Aniddan', 'Meeeth', 'Ruthul', 'Reeshann', 'Salaleee', 'Satiti', 'Arushika']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.9370
# Epoch 120/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9649
# diversity: 0.5
# Generated Text : ['Sarshila', 'Ratish', 'Ramamesha', 'Phayanta', 'Dengata', 'Vansha', 'Rasha', 'Ashusha', 'Aamanda', 'Shayan', 'Aeethara', 'Arti', 'Shum', 'Ammal', 'Sajeeta', 'Niti', 'Nushi', 'Karshi', 'Sadaksh', 'Mantala', 'Najeeda', 'Nashani', 'Sa', 'Ronjiya', 'Sama', 'Arushu', 'Ashiti', 'Amnit']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.9649
# Epoch 121/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9199
# diversity: 0.5
# Generated Text : ['ru', 'Amyanya', 'Aminma', 'Kurishi', 'Ani', 'Abhisha', 'Andiry', 'Nimif', 'Abhiyan', 'Ayandhil', 'Mihand', 'Mahal', 'Maakakaaa', 'Panyan', 'Shurama', 'Shrryabhu', 'Savmrshi', 'Samamara', 'Bhannshra', 'Shuryas', 'Suriya', 'Arshita', 'Somivi', 'Maniki', 'Anisha', 'Arishid', 'Adid']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.9199
# Epoch 122/150
# 12/12 [==============================] - ETA: 0s - loss: 0.9187
# diversity: 0.5
# Generated Text : ['Pranee', 'Shrigageeepa', 'Sam', 'Surjeep', 'Saryani', 'Sanda', 'Shameen', 'Surhijan', 'Suribh', 'Saryanik', 'Shudhar', 'Shobhan', 'Shalvav', 'Reenadra', 'Viree', 'Suram', 'Ashil', 'Anita', 'Anudi', 'Andhu', 'Abhwan', 'Sraman', 'Suram', 'Shrita', 'Shudya', 'Shurila', 'Samini', 'Shi']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.9187
# Epoch 123/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8842
# diversity: 0.5
# Generated Text : ['Shribana', 'Shrgyanja', 'Shryayak', 'Sundala', 'Prnij', 'Sumadra', 'Praniti', 'Shuryama', 'Venrasha', 'Viran', 'Sajeetha', 'Srryayan', 'Sumal', 'Sojjil', 'Sanika', 'Shujala', 'Shreyanshi', 'Shryamash', 'Suvammaya', 'Pajjeta', 'Nalila', 'Paajesha', 'Virageeepa', 'Vasha']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.8842
# Epoch 124/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8909
# diversity: 0.5
# Generated Text : ['yanshi', 'Soratansha', 'Suryiti', 'Shreyati', 'Sunkan', 'Sharnjeep', 'Sorusha', 'Anshin', 'Suryishi', 'Shadati', 'Sandha', 'Shureepa', 'Sanyandeep', 'Sorita', 'Antili', 'Shushibha', 'Surmisha', 'Shamati', 'Shanthal', 'Sharsha', 'Shryavansh', 'Shudaash', 'Sondraya', 'Sa']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.8909
# Epoch 125/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8621
# diversity: 0.5
# Generated Text : ['Alatha', 'Aayashi', 'Aidan', 'ArtitanAriri', 'Aruni', 'ApbhandAan', 'Aruuudha', 'Abhabha', 'Arannira', 'Anidi', 'Anidi', 'Abhatia', 'Anurin', 'Sumilee', 'Arithit', 'Arankura', 'Hendhar', 'Naeetaa', 'Nayanjee', 'Prashun', 'Shalatok', 'Suddada', 'Sheepan', 'Shanvanshi', 'S']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.8621
# Epoch 126/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8509
# diversity: 0.5
# Generated Text : ['athan', 'Niran', 'Mradik', 'Mara', 'Akasha', 'Anabha', 'Arushu', 'Arashan', 'Arriti', 'Arandha', 'Abhin', 'Andhum', 'Ariman', 'Arashia', 'Anidi', 'Andih', 'AbhaanAa', 'Arnidi', 'Arshiba', 'Sramar', 'Sharam', 'Seetharatha', 'Rargeep', 'Shreesh', 'Sorila', 'Sushi', 'Arshin', 'Srri']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.8509
# Epoch 127/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8478
# diversity: 0.5
# Generated Text : ['Vreshanta', 'Ramandeep', 'Shohalan', 'Sarnshila', 'Shuriya', 'Shrutayan', 'Sendala', 'Rennn', 'Dila', 'Soshura', 'Sariya', 'Surit', 'Anita', 'Shijil', 'Shuraleep', 'Soryannya', 'Sura', 'Veejyan', 'Nitha', 'Visin', 'Arabhashi', 'Surbhir', 'Shuraya', 'Shaeetha', 'Shrvala', 'D']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.8478
# Epoch 128/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8203
# diversity: 0.5
# Generated Text : ['idi', 'Sarika', 'Shusha', 'Shrvenv', 'Shuvala', 'Sanjar', 'Sarin', 'Arushi', 'Arin', 'Ardidhi', 'Anid', 'Anida', 'Adikan', 'Aida', 'Arika', 'Aridai', 'Aqibha', 'Aburusha', 'Abriti', 'Akhurdhal', 'Ahindera', 'Karusha', 'Marika', 'Moika', 'Jakakarakeera', 'Pranyal', 'Shama', 'Suura', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.8203
# Epoch 129/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8066
# diversity: 0.5
# Generated Text : ['Rutila', 'Vanjesh', 'Rajajoshwa', 'Shubhosh', 'Sobhala', 'Sakai', 'Pranya', 'Shuma', 'Shubham', 'Srajani', 'Sabharoshi', 'Sarushi', 'Surthiya', 'Surakal', 'Shalan', 'Solila', 'Shalush', 'Soralibh', 'Sadrita', 'Sathala', 'Sameent', 'Neeshan', 'Ragjees', 'Swabhan', 'Sobhun', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.8066
# Epoch 130/150
# 12/12 [==============================] - ETA: 0s - loss: 0.8074
# diversity: 0.5
# Generated Text : ['Ranya', 'Veentha', 'Vireshwa', 'Maretes', 'Makakhika', 'Manandda', 'Meetan', 'Anili', 'Anshira', 'Sharuud', 'Shryanti', 'Sundal', 'Shamnini', 'Soriyan', 'Jureet', 'Srutiyan', 'Sumal', 'Sumall', 'Shalila', 'Shidala', 'Shuransh', 'Srryavin', 'Sumala', 'Veeenthan', 'Virajee']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.8074
# Epoch 131/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7987
# diversity: 0.5
# Generated Text : ['arish', 'Jarishik', 'Sadayakeea', 'Nanthi', 'Ari', 'Ashishaa', 'Arunil', 'Shameeta', 'Shurmala', 'Shareeea', 'Sharthola', 'Saranja', 'Vingeera', 'Prayanya', 'Sharila', 'Saranjal', 'Soonsil', 'Samira', 'Suryalah', 'Pranya', 'Surmar', 'Sardipa', 'Sariyal', 'Saradha', 'Shore']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.7987
# Epoch 132/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7611
# diversity: 0.5
# Generated Text : ['sh', 'Supayansi', 'Abhashana', 'Summiree', 'Paryankan', 'Galeen', 'Geeshana', 'Raggeesh', 'Shama', 'Sakyan', 'Amiyan', 'Pryeeta', 'Ankal', 'Pyanee', 'Praren', 'Marit', 'Mandid', 'Mohil', 'Moolil', 'Maanika', 'Maida', 'Meeeaa', 'Nanith', 'Abhid', 'Tarush', 'Sraramit', 'Sadhamal', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.7611
# Epoch 133/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7701
# diversity: 0.5
# Generated Text : ['nshi', 'Abashansha', 'Sudureep', 'Najetala', 'Shilal', 'Shuvendaleep', 'Laresh', 'Vidi', 'Ashiz', 'Ashinala', 'Shiray', 'Surital', 'Shailan', 'Seendalten', 'Rentin', 'Vish', 'Ansil', 'Alishi', 'Modif', 'Munid', 'Meetan', 'Neetela', 'Nitil', 'Nimin', 'Magish', 'Mhaa', 'Mokika', 'Ma']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.7701
# Epoch 134/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7506
# diversity: 0.5
# Generated Text : ['Namam', 'Naileep', 'Samala', 'Saleeparati', 'Karusha', 'Maritika', 'Akhayaatha', 'Tanddi', 'Meesh', 'Matita', 'Mankal', 'Maheen', 'Neeshan', 'Prashika', 'Sakarti', 'Anmal', 'Sheeepa', 'Shulal', 'Shageedhra', 'Ramish', 'Shragshikeep', 'Samarsha', 'Agisha', 'Amanit', 'Shurs']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.7506
# Epoch 135/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7346
# diversity: 0.5
# Generated Text : ['sha', 'Atik', 'Hanjvi', 'Dii', 'Jahanshara', 'Shareer', 'Sharyansh', 'Divanshika', 'Prayaya', 'Anikha', 'Aridia', 'Prashi', 'Akashakakadita', 'Heendata', 'Vanida', 'Sahar', 'Abhujala', 'Sarini', 'Sorita', 'Shurala', 'Samiti', 'Ranusha', 'Saryajesh', 'Soodibhan', 'Sartila', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.7346
# Epoch 136/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7086
# diversity: 0.5
# Generated Text : ['yikan', 'Andhandhi', 'Shureesha', 'Shryaatha', 'Sumimar', 'Jaheenda', 'Shrgeeepa', 'Savvandi', 'Sumrra', 'Tashini', 'Sargeeshwa', 'Swatyansh', 'Sadhaya', 'Seetaathant', 'Ramandra', 'Sudhal', 'Samal', 'Sadyipi', 'Sumil', 'Anshil', 'Shumibr', 'Surthilan', 'Seethanti', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.7086
# Epoch 137/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6931
# diversity: 0.5
# Generated Text : ['i', 'Aandha', 'Adubhan', 'Neeshnni', 'Shwanyan', 'Jenthant', 'Neshith', 'Swwata', 'Soniy', 'Shidila', 'Suriya', 'Shujiya', 'Suriya', 'Surtit', 'Anudib', 'Shubhini', 'Shrrthinra', 'Shamarsh', 'Panyanyi', 'Shugdeeth', 'Krrtiyan', 'Surath', 'Atika', 'Shayaneee', 'Nrrthiti', 'Ar']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.6931
# Epoch 138/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6933
# diversity: 0.5
# Generated Text : ['Meeetaa', 'Nailileep', 'Sharagojeepa', 'Sahagyan', 'Shila', 'Shujila', 'Sariya', 'Suridi', 'Arnidi', 'Shubwa', 'Aruryen', 'Nrmita', 'Prakeethan', 'Nitala', 'Nishara', 'Sawan', 'Soyin', 'Jujila', 'Viidir', 'Juhijal', 'Subhira', 'Surita', 'Shrduyan', 'Surati', 'Rojeeta', 'Nit']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.6933
# Epoch 139/150
# 12/12 [==============================] - ETA: 0s - loss: 0.7025
# diversity: 0.5
# Generated Text : ['havan', 'Deeparasha', 'Ramurujeep', 'Shayanya', 'Shurama', 'Sharyani', 'Janvir', 'Shursha', 'Soriyan', 'Surthal', 'Shulan', 'Suriyan', 'Nrruta', 'Nureep', 'Srriyan', 'Surati', 'Nomila', 'Souryoha', 'Soudida', 'Sarabha', 'Santil', 'Shoshila', 'Souriti', 'Shurada', 'Shanin', '']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.7025
# Epoch 140/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6460
# diversity: 0.5
# Generated Text : ['ik', 'Sukashaka', 'Paneep', 'Shal', 'Shalil', 'Shigal', 'Shulal', 'Shilin', 'Surikan', 'Sruman', 'Surijee', 'Srujila', 'Sharila', 'Sorini', 'Sharila', 'Sarshi', 'Surayankkashanid', 'Reeenn', 'Ranjaj', 'Sooil', 'Sodilal', 'Sushil', 'Soubhil', 'Somila', 'Sokiyan', 'Shulan', 'Shul']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.6460
# Epoch 141/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6602
# diversity: 0.5
# Generated Text : ['Aniti', 'Ashisha', 'Arakyushir', 'Ammid', 'Andith', 'Ammanti', 'Andiy', 'Aniti', 'Aritikaniidireeem', 'Karitik', 'Akhibha', 'Abhanda', 'Ranshi', 'Prashun', 'Modin', 'Aikakhikai', 'Anyan', 'Arasha', 'Aranika', 'Prayanuramar', 'Nigeepa', 'Sargiya', 'Shrida', 'Shutal', 'Shm']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.6602
# Epoch 142/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6374
# diversity: 0.5
# Generated Text : ['tFan', 'Prani', 'Raje', 'rajakh', 'Karika', 'Shidaa', 'Sokhal', 'Sanal', 'Somin', 'Sriti', 'Arushi', 'Andhi', 'Heshmrrat', 'Neethath', 'Neetana', 'Neetan', 'Ral', 'Dila', 'Dani', 'Dallasha', 'Mabhankak', 'Maika', 'Maikar', 'Mahakakakeepa', 'Paannala', 'Panush', 'Manig', 'Moshika', 'A']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.6374
# Epoch 143/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6377
# diversity: 0.5
# Generated Text : ['Soryayan', 'Surayamar', 'Shuraya', 'Shryvann', 'Shira', 'Shupil', 'Sunika', 'Sahikan', 'Surayan', 'Suryanjee', 'Srugiti', 'Shuraya', 'Soushira', 'Samikep', 'Shuyamama', 'Samara', 'Sheenvan', 'Shura', 'Shreviv', 'Shulila', 'Shakreeea', 'Prnyhyan', 'Surama', 'Shuree', 'Shi']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.6377
# Epoch 144/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6066
# diversity: 0.5
# Generated Text : ['nta', 'Sayak', 'Jakhaka', 'Akayan', 'Neevan', 'Reet', 'Neshin', 'Sali', 'Sankiy', 'Mahan', 'Meeta', 'Nunyi', 'Anpp', 'Yali', 'Andid', 'Kishan', 'Artha', 'Ammandira', 'Pranhan', 'Paunsha', 'Arashai', 'Aankudha', 'Amansha', 'Aranyandi', 'Khira', 'Prusha', 'Ankyan', 'Abhika', 'Ankeen', 'Ne']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.6066
# Epoch 145/150
# 12/12 [==============================] - ETA: 0s - loss: 0.5974
# diversity: 0.5
# Generated Text : ['ukimamrimi', 'Meendh', 'Nethant', 'Shuvanti', 'Anmuruma', 'Yeshhinda', 'Sobhibhashaka', 'Sakavisha', 'Ammita', 'Sareeha', 'Sathinla', 'Sarijil', 'Suritil', 'Shuliti', 'Surdhila', 'Shubhani', 'Shubhin', 'Sumidi', 'Sirahi', 'Shatindar', 'Shmulan', 'SobhipinSSwalabS']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.5974
# Epoch 146/150
# 12/12 [==============================] - ETA: 0s - loss: 0.6144
# diversity: 0.5
# Generated Text : ['uub', 'Shara', 'Sujila', 'Sahajan', 'Subhareethan', 'Rarmjeep', 'Sursha', 'Ashini', 'Samiki', 'Shilayaneeer', 'Namrerr', 'Shraya', 'Soyit', 'Santilaa', 'Prajeep', 'Sareeta', 'Rati', 'Giti', 'Visha', 'Asikish', 'AshitaAAtit', 'Ammiti', 'Veendhan', 'Artita', 'Aniki', 'Abhigaha']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.6144
# Epoch 147/150
# 12/12 [==============================] - ETA: 0s - loss: 0.5600
# diversity: 0.5
# Generated Text : ['Arikun', 'Amima', 'Arishi', 'Andhin', 'Shuvandi', 'Shumla', 'Sheeeta', 'Shuvalan', 'Suram', 'Surjeep', 'Sotili', 'Sharida', 'Shushib', 'Sobhib', 'Shushi', 'Sankil', 'Shala', 'Sikan', 'Shalal', 'Suri', 'Sunshid', 'Soribhi', 'Sushibha', 'Samiya', 'Suriti', 'Arshita', 'Shurit', 'Shu']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.5600
# Epoch 148/150
# 12/12 [==============================] - ETA: 0s - loss: 0.5741
# diversity: 0.5
# Generated Text : ['eeshathan', 'Reshan', 'Sukshik', 'Shakanka', 'Prayan', 'Neeranta', 'Nrreepa', 'Pruvan', 'Jaleeta', 'Vindaa', 'Vijeet', 'Nititi', 'Abhisya', 'Surasha', 'Sumali', 'Prakhan', 'Neeransh', 'Niram', 'Seedh', 'Shoyal', 'Shkika', 'Sharaka', 'Sunav', 'Shujan', 'Shulila', 'Surusha', 'Sur']
#
# 12/12 [==============================] - 15s 1s/step - loss: 0.5741
# Epoch 149/150
# 12/12 [==============================] - ETA: 0s - loss: 0.5738
# diversity: 0.5
# Generated Text : ['an', 'Rajeen', 'Prajenn', 'Shalanshi', 'Shussha', 'Shushir', 'Sukshi', 'Aathan', 'Anshin', 'Suruyi', 'Sumiti', 'Shayanteee', 'Shathurya', 'Sharetha', 'Shuvansha', 'Sharaja', 'Sudhar', 'Shamara', 'Sanyan', 'Shaggeeera', 'Nrrtiti', 'Rani', 'Pranjeet', 'Paanyak', 'Neeeataath']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.5738
# Epoch 150/150
# 12/12 [==============================] - ETA: 0s - loss: 0.5282
# diversity: 0.5
# Generated Text : ['hini', 'Panshi', 'Mahindura', 'Bhansha', 'Shoyal', 'Soshil', 'Shiti', 'Shuli', 'Shila', 'Shalil', 'Shiyan', 'Suryan', 'Shryan', 'Soulil', 'Sharan', 'Sanval', 'Sojella', 'Soorila', 'Samir', 'Suujal', 'Sajiyan', 'Surata', 'Ronjila', 'Salil', 'Soushi', 'Sanjil', 'Suriya', 'Snitiya', 'Sa']
#
# 12/12 [==============================] - 16s 1s/step - loss: 0.5282
